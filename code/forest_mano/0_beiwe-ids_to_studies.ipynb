# %% [markdown]
# Task: merge participant demographics info in `HOPE_paper2_demographics.csv` with `*_download_participant.csv` tables obtained from the Beiwe server
#
# Why? need beiwe-id to study-id mapping in order to download data from the Beiwe server

# %%
import os
import glob
import pandas as pd
import yaml

# import hardcoded variables e.g., study name to ID mappings, directory paths, etc. from config file
CONFIG_PATH = "../../config/HOPE_config.yaml"
CONFIG_DIR = os.path.dirname(CONFIG_PATH)

with open(CONFIG_PATH, "r") as f:
    config = yaml.safe_load(f)
dload_part_dir = os.path.abspath(os.path.join(CONFIG_DIR, config["download_participants_dir"]))
data_dir = os.path.abspath(os.path.join(CONFIG_DIR, config["data_dir"]))

# get all CSV files matching the naming pattern "*_download_participants.csv" inside download_participants" directory
notebook_dir = os.getcwd()

# define the relative path to the folder containing CSV files
csv_files = glob.glob(os.path.join(dload_part_dir, "*_download_participants.csv"))

# %%
csv_files
# Out:
# ['/n/onnela_dp_l3/Lab/HOPE/beiwe/data/download_participants/test2_download_participants.csv',
#  '/n/onnela_dp_l3/Lab/HOPE/beiwe/data/download_participants/test_download_participants.csv',
#  '/n/onnela_dp_l3/Lab/HOPE/beiwe/data/download_participants/trial_download_participants.csv',
#  '/n/onnela_dp_l3/Lab/HOPE/beiwe/data/download_participants/trial_phase2_download_participants.csv',
#  '/n/onnela_dp_l3/Lab/HOPE/beiwe/data/download_participants/trial_phase2_passive_data_only_download_participants.csv',
#  '/n/onnela_dp_l3/Lab/HOPE/beiwe/data/download_participants/troubleshooting_download_participants.csv']

# %%
study_name_to_id = config["study_name_to_id"]
print(study_name_to_id)
# Out:
# 59c2b5b4388cd6715a958247
# {'test': '59c2b5b4388cd6715a958247', 'test2': '5h7D9XT2vrN3BWkdcbYVNtpI', 'trial': '588224eff4d48a76f488cdfd', 'trial_phase2': '598365d5388cd66a62ac1f9e', 'trial_phase2_passive_data_only': '5a2ae1dc03d3c425ef0ea752', 'troubleshooting': '5a79f17d03d3c45080924ed4'}

# %%
# List to store dataframes
dataframes = []

for file_path in csv_files:
    # Extract the base filename 
    filename = os.path.basename(file_path)

    # Extract the study name from the filename before "_download_participants.csv"
    study_name = filename.replace("_download_participants.csv", "")

    # Check if the extracted study name exists in the dictionary
    if study_name in study_name_to_id:
        study_id = study_name_to_id[study_name]  # Lookup Study_ID
    else:
        print(f"Skipping {filename} (Study name '{study_name}' not found in dictionary)")
        continue  # Skip this file if study name is not in the dictionary

    # read to pandas df
    df = pd.read_csv(file_path)
    # print(df.head())
    # Ensure "Patient ID" column exists before merging
    if "Patient ID" in df.columns:
        # Add the new columns
        df["Study_ID"] = study_id
        df["Study_Name"] = study_name

        # Append the modified dataframe to the list
        dataframes.append(df)

        print(f"Loaded {filename} ({study_name}, ID: {study_id}) with {df.shape[0]} rows")
    else:
        print(f"Skipping {filename} (Missing 'Patient ID' column)")
# Out:
#    Created On Patient ID    Status OS Type    First Registration Date  \
# 0  2020-07-30   h6qsyvyf  Inactive     IOS  2020-07-30 14:00:00 (UTC)
# 1  2020-05-02   k75kp9va  Inactive     IOS  2020-05-04 02:00:00 (UTC)
# 2  2020-04-29   lz3g8h3d  Inactive     IOS  2020-04-29 13:00:00 (UTC)
# 3  2020-05-07   sqdpv78e  Inactive     IOS  2020-05-07 17:00:00 (UTC)
#
#    Last Registration  Last Upload  Last Survey Download  Last Set Password  \
# 0                NaN          NaN                   NaN                NaN
# 1                NaN          NaN                   NaN                NaN
# 2                NaN          NaN                   NaN                NaN
# 3                NaN          NaN                   NaN                NaN
#
#    Last Push Token Update  Last Device Settings Update  Last OS Version  \
# 0                     NaN                          NaN              NaN
# 1                     NaN                          NaN              NaN
# 2                     NaN                          NaN              NaN
# 3                     NaN                          NaN              NaN
#
#    App Version Code  App Version Name  Last Heartbeat
# 0               NaN               NaN             NaN
# 1               NaN               NaN             NaN
# 2               NaN               NaN             NaN
# 3               NaN               NaN             NaN
# Loaded test2_download_participants.csv (test2, ID: 5h7D9XT2vrN3BWkdcbYVNtpI) with 4 rows
#    Created On Patient ID          Status OS Type    First Registration Date  \
# 0  2020-02-07   1wlgkwod  Not Registered     NaN                        NaN
# 1  2019-11-14   hc5gijag  Not Registered     NaN                        NaN
# 2  2019-11-14   v2p9w92z  Not Registered     IOS  2019-11-14 16:00:00 (UTC)
#
#    Last Registration  Last Upload  Last Survey Download  Last Set Password  \
# 0                NaN          NaN                   NaN                NaN
# 1                NaN          NaN                   NaN                NaN
# 2                NaN          NaN                   NaN                NaN
#
#    Last Push Token Update  Last Device Settings Update  Last OS Version  \
# 0                     NaN                          NaN              NaN
# 1                     NaN                          NaN              NaN
# 2                     NaN                          NaN              NaN
#
#    App Version Code  App Version Name  Last Heartbeat
# 0               NaN               NaN             NaN
# 1               NaN               NaN             NaN
# 2               NaN               NaN             NaN
# Loaded test_download_participants.csv (test, ID: 59c2b5b4388cd6715a958247) with 3 rows
#    Created On Patient ID    Status  OS Type    First Registration Date  \
# 0  2017-05-03   4458ann3  Inactive      IOS  2017-05-03 16:00:00 (UTC)
# 1  2017-04-24   52td8unr  Inactive  ANDROID  2017-04-24 15:00:00 (UTC)
# 2  2017-04-26   67zqexic  Inactive  ANDROID  2017-04-26 15:00:00 (UTC)
# 3  2017-05-04   7h42nxij  Inactive      IOS  2017-05-04 19:00:00 (UTC)
# 4  2017-03-01   gxz9uy78  Inactive      IOS  2017-03-01 22:00:00 (UTC)
#
#    Last Registration  Last Upload  Last Survey Download  Last Set Password  \
# 0                NaN          NaN                   NaN                NaN
# 1                NaN          NaN                   NaN                NaN
# 2                NaN          NaN                   NaN                NaN
# 3                NaN          NaN                   NaN                NaN
# 4                NaN          NaN                   NaN                NaN
#
#    Last Push Token Update  Last Device Settings Update  Last OS Version  \
# 0                     NaN                          NaN              NaN
# 1                     NaN                          NaN              NaN
# 2                     NaN                          NaN              NaN
# 3                     NaN                          NaN              NaN
# 4                     NaN                          NaN              NaN
#
#    App Version Code  App Version Name  Last Heartbeat
# 0               NaN               NaN             NaN
# 1               NaN               NaN             NaN
# 2               NaN               NaN             NaN
# 3               NaN               NaN             NaN
# 4               NaN               NaN             NaN
# Loaded trial_download_participants.csv (trial, ID: 588224eff4d48a76f488cdfd) with 16 rows
#    Created On Patient ID    Status  OS Type    First Registration Date  \
# 0  2018-01-19   1s5wlcm6  Inactive  ANDROID  2018-01-19 16:00:00 (UTC)
# 1  2018-05-22   2n18iikg  Inactive      IOS  2018-06-06 19:00:00 (UTC)
# 2  2018-05-22   2umdx87r  Inactive      IOS  2019-03-21 19:00:00 (UTC)
# 3  2017-12-08   41n4f9xk  Inactive      IOS  2017-12-08 21:00:00 (UTC)
# 4  2018-05-22   4aczi869  Inactive      IOS  2019-06-10 18:00:00 (UTC)
#
#    Last Registration Last Upload  Last Survey Download  Last Set Password  \
# 0                NaN         NaN                   NaN                NaN
# 1                NaN         NaN                   NaN                NaN
# 2                NaN         NaN                   NaN                NaN
# 3                NaN         NaN                   NaN                NaN
# 4                NaN         NaN                   NaN                NaN
#
#    Last Push Token Update  Last Device Settings Update  Last OS Version  \
# 0                     NaN                          NaN              NaN
# 1                     NaN                          NaN              NaN
# 2                     NaN                          NaN              NaN
# 3                     NaN                          NaN              NaN
# 4                     NaN                          NaN              NaN
#
#    App Version Code  App Version Name  Last Heartbeat
# 0               NaN               NaN             NaN
# 1               NaN               NaN             NaN
# 2               NaN               NaN             NaN
# 3               NaN               NaN             NaN
# 4               NaN               NaN             NaN
# Loaded trial_phase2_download_participants.csv (trial_phase2, ID: 598365d5388cd66a62ac1f9e) with 70 rows
#    Created On Patient ID    Status  OS Type    First Registration Date  \
# 0  2018-05-22   1rkt87d2  Inactive      IOS  2019-04-16 19:00:00 (UTC)
# 1  2018-05-22    3j2fdbb  Inactive  ANDROID  2018-09-13 16:00:00 (UTC)
# 2  2018-05-22   3tg2dbdl  Inactive      IOS  2019-12-20 17:00:00 (UTC)
# 3  2018-05-22   4fyd1ssv  Inactive      IOS  2019-02-28 15:00:00 (UTC)
# 4  2018-05-22   4s7o5pps  Inactive      IOS  2018-09-25 17:00:00 (UTC)
#
#    Last Registration Last Upload Last Survey Download  Last Set Password  \
# 0                NaN         NaN                  NaN                NaN
# 1                NaN         NaN                  NaN                NaN
# 2                NaN         NaN                  NaN                NaN
# 3                NaN         NaN                  NaN                NaN
# 4                NaN         NaN                  NaN                NaN
#
#    Last Push Token Update  Last Device Settings Update  Last OS Version  \
# 0                     NaN                          NaN              NaN
# 1                     NaN                          NaN              NaN
# 2                     NaN                          NaN              NaN
# 3                     NaN                          NaN              NaN
# 4                     NaN                          NaN              NaN
#
#    App Version Code  App Version Name  Last Heartbeat
# 0               NaN               NaN             NaN
# 1               NaN               NaN             NaN
# 2               NaN               NaN             NaN
# 3               NaN               NaN             NaN
# 4               NaN               NaN             NaN
# Loaded trial_phase2_passive_data_only_download_participants.csv (trial_phase2_passive_data_only, ID: 5a2ae1dc03d3c425ef0ea752) with 62 rows
#    Created On Patient ID    Status  OS Type    First Registration Date  \
# 0  2018-02-11   4sgli41i  Inactive      IOS  2018-02-12 02:00:00 (UTC)
# 1  2018-02-21   5raarz6v  Inactive  ANDROID  2018-02-21 20:00:00 (UTC)
# 2  2018-02-06   izdho8xu  Inactive      IOS  2018-02-06 21:00:00 (UTC)
#
#    Last Registration  Last Upload  Last Survey Download  Last Set Password  \
# 0                NaN          NaN                   NaN                NaN
# 1                NaN          NaN                   NaN                NaN
# 2                NaN          NaN                   NaN                NaN
#
#    Last Push Token Update  Last Device Settings Update  Last OS Version  \
# 0                     NaN                          NaN              NaN
# 1                     NaN                          NaN              NaN
# 2                     NaN                          NaN              NaN
#
#    App Version Code  App Version Name  Last Heartbeat
# 0               NaN               NaN             NaN
# 1               NaN               NaN             NaN
# 2               NaN               NaN             NaN
# Loaded troubleshooting_download_participants.csv (troubleshooting, ID: 5a79f17d03d3c45080924ed4) with 3 rows

# %%
dataframes
# Out:
# [   Created On Patient ID    Status OS Type    First Registration Date  \
#  0  2020-07-30   h6qsyvyf  Inactive     IOS  2020-07-30 14:00:00 (UTC)
#  1  2020-05-02   k75kp9va  Inactive     IOS  2020-05-04 02:00:00 (UTC)
#  2  2020-04-29   lz3g8h3d  Inactive     IOS  2020-04-29 13:00:00 (UTC)
#  3  2020-05-07   sqdpv78e  Inactive     IOS  2020-05-07 17:00:00 (UTC)
#
#     Last Registration  Last Upload  Last Survey Download  Last Set Password  \
#  0                NaN          NaN                   NaN                NaN
#  1                NaN          NaN                   NaN                NaN
#  2                NaN          NaN                   NaN                NaN
#  3                NaN          NaN                   NaN                NaN
#
#     Last Push Token Update  Last Device Settings Update  Last OS Version  \
#  0                     NaN                          NaN              NaN
#  1                     NaN                          NaN              NaN
#  2                     NaN                          NaN              NaN
#  3                     NaN                          NaN              NaN
#
#     App Version Code  App Version Name  Last Heartbeat  \
#  0               NaN               NaN             NaN
#  1               NaN               NaN             NaN
#  2               NaN               NaN             NaN
#  3               NaN               NaN             NaN
#
#                     Study_ID Study_Name
#  0  5h7D9XT2vrN3BWkdcbYVNtpI      test2
#  1  5h7D9XT2vrN3BWkdcbYVNtpI      test2
#  2  5h7D9XT2vrN3BWkdcbYVNtpI      test2
#  3  5h7D9XT2vrN3BWkdcbYVNtpI      test2  ,
#     Created On Patient ID          Status OS Type    First Registration Date  \
#  0  2020-02-07   1wlgkwod  Not Registered     NaN                        NaN
#  1  2019-11-14   hc5gijag  Not Registered     NaN                        NaN
#  2  2019-11-14   v2p9w92z  Not Registered     IOS  2019-11-14 16:00:00 (UTC)
#
#     Last Registration  Last Upload  Last Survey Download  Last Set Password  \
#  0                NaN          NaN                   NaN                NaN
#  1                NaN          NaN                   NaN                NaN
#  2                NaN          NaN                   NaN                NaN
#
#     Last Push Token Update  Last Device Settings Update  Last OS Version  \
#  0                     NaN                          NaN              NaN
#  1                     NaN                          NaN              NaN
#  2                     NaN                          NaN              NaN
#
#     App Version Code  App Version Name  Last Heartbeat  \
#  0               NaN               NaN             NaN
#  1               NaN               NaN             NaN
#  2               NaN               NaN             NaN
#
#                     Study_ID Study_Name
#  0  59c2b5b4388cd6715a958247       test
#  1  59c2b5b4388cd6715a958247       test
#  2  59c2b5b4388cd6715a958247       test  ,
#      Created On Patient ID          Status  OS Type    First Registration Date  \
#  0   2017-05-03   4458ann3        Inactive      IOS  2017-05-03 16:00:00 (UTC)
#  1   2017-04-24   52td8unr        Inactive  ANDROID  2017-04-24 15:00:00 (UTC)
#  2   2017-04-26   67zqexic        Inactive  ANDROID  2017-04-26 15:00:00 (UTC)
#  3   2017-05-04   7h42nxij        Inactive      IOS  2017-05-04 19:00:00 (UTC)
#  4   2017-03-01   gxz9uy78        Inactive      IOS  2017-03-01 22:00:00 (UTC)
#  5   2017-04-19   jy8yzsap        Inactive  ANDROID  2017-04-19 13:00:00 (UTC)
#  6   2018-05-22   kvur4ggv  Not Registered      NaN                        NaN
#  7   2018-05-22   ljiu9jzq  Not Registered      NaN                        NaN
#  8   2017-04-12   md7fnll7        Inactive      IOS  2017-04-12 20:00:00 (UTC)
#  9   2017-05-02   opzkrwv5        Inactive      IOS  2017-05-03 00:00:00 (UTC)
#  10  2017-04-28   piiua4us        Inactive      IOS  2017-04-28 18:00:00 (UTC)
#  11  2017-04-20   q21jny47        Inactive      IOS  2017-04-20 19:00:00 (UTC)
#  12  2018-05-22   rx1icbvn  Not Registered      NaN                        NaN
#  13  2017-04-19   wgs5rptp        Inactive      IOS  2017-04-19 17:00:00 (UTC)
#  14  2017-04-13   wrb5oh7u        Inactive      IOS  2017-04-13 17:00:00 (UTC)
#  15  2017-03-10   x8k4rn9q        Inactive      IOS  2017-03-10 20:00:00 (UTC)
#
#      Last Registration  Last Upload  Last Survey Download  Last Set Password  \
#  0                 NaN          NaN                   NaN                NaN
#  1                 NaN          NaN                   NaN                NaN
#  2                 NaN          NaN                   NaN                NaN
#  3                 NaN          NaN                   NaN                NaN
#  4                 NaN          NaN                   NaN                NaN
#  5                 NaN          NaN                   NaN                NaN
#  6                 NaN          NaN                   NaN                NaN
#  7                 NaN          NaN                   NaN                NaN
#  8                 NaN          NaN                   NaN                NaN
#  9                 NaN          NaN                   NaN                NaN
#  10                NaN          NaN                   NaN                NaN
#  11                NaN          NaN                   NaN                NaN
#  12                NaN          NaN                   NaN                NaN
#  13                NaN          NaN                   NaN                NaN
#  14                NaN          NaN                   NaN                NaN
#  15                NaN          NaN                   NaN                NaN
#
#      Last Push Token Update  Last Device Settings Update  Last OS Version  \
#  0                      NaN                          NaN              NaN
#  1                      NaN                          NaN              NaN
#  2                      NaN                          NaN              NaN
#  3                      NaN                          NaN              NaN
#  4                      NaN                          NaN              NaN
#  5                      NaN                          NaN              NaN
#  6                      NaN                          NaN              NaN
#  7                      NaN                          NaN              NaN
#  8                      NaN                          NaN              NaN
#  9                      NaN                          NaN              NaN
#  10                     NaN                          NaN              NaN
#  11                     NaN                          NaN              NaN
#  12                     NaN                          NaN              NaN
#  13                     NaN                          NaN              NaN
#  14                     NaN                          NaN              NaN
#  15                     NaN                          NaN              NaN
#
#      App Version Code  App Version Name  Last Heartbeat  \
#  0                NaN               NaN             NaN
#  1                NaN               NaN             NaN
#  2                NaN               NaN             NaN
#  3                NaN               NaN             NaN
#  4                NaN               NaN             NaN
#  5                NaN               NaN             NaN
#  6                NaN               NaN             NaN
#  7                NaN               NaN             NaN
#  8                NaN               NaN             NaN
#  9                NaN               NaN             NaN
#  10               NaN               NaN             NaN
#  11               NaN               NaN             NaN
#  12               NaN               NaN             NaN
#  13               NaN               NaN             NaN
#  14               NaN               NaN             NaN
#  15               NaN               NaN             NaN
#
#                      Study_ID Study_Name
#  0   588224eff4d48a76f488cdfd      trial
#  1   588224eff4d48a76f488cdfd      trial
#  2   588224eff4d48a76f488cdfd      trial
#  3   588224eff4d48a76f488cdfd      trial
#  4   588224eff4d48a76f488cdfd      trial
#  5   588224eff4d48a76f488cdfd      trial
#  6   588224eff4d48a76f488cdfd      trial
#  7   588224eff4d48a76f488cdfd      trial
#  8   588224eff4d48a76f488cdfd      trial
#  9   588224eff4d48a76f488cdfd      trial
#  10  588224eff4d48a76f488cdfd      trial
#  11  588224eff4d48a76f488cdfd      trial
#  12  588224eff4d48a76f488cdfd      trial
#  13  588224eff4d48a76f488cdfd      trial
#  14  588224eff4d48a76f488cdfd      trial
#  15  588224eff4d48a76f488cdfd      trial  ,
#      Created On Patient ID    Status  OS Type    First Registration Date  \
#  0   2018-01-19   1s5wlcm6  Inactive  ANDROID  2018-01-19 16:00:00 (UTC)
#  1   2018-05-22   2n18iikg  Inactive      IOS  2018-06-06 19:00:00 (UTC)
#  2   2018-05-22   2umdx87r  Inactive      IOS  2019-03-21 19:00:00 (UTC)
#  3   2017-12-08   41n4f9xk  Inactive      IOS  2017-12-08 21:00:00 (UTC)
#  4   2018-05-22   4aczi869  Inactive      IOS  2019-06-10 18:00:00 (UTC)
#  ..         ...        ...       ...      ...                        ...
#  65  2018-05-11   xcdydxji  Inactive  ANDROID  2018-05-11 14:00:00 (UTC)
#  66  2018-05-22   xfd4twop  Inactive      IOS  2019-02-08 15:00:00 (UTC)
#  67  2018-05-22   ychlwvnz  Inactive  ANDROID  2019-07-11 17:00:00 (UTC)
#  68  2018-05-22   zj4gbhlp  Inactive      IOS  2019-02-11 17:00:00 (UTC)
#  69  2017-12-08   zo8vuchq  Inactive      IOS  2017-12-08 19:00:00 (UTC)
#
#      Last Registration Last Upload  Last Survey Download  Last Set Password  \
#  0                 NaN         NaN                   NaN                NaN
#  1                 NaN         NaN                   NaN                NaN
#  2                 NaN         NaN                   NaN                NaN
#  3                 NaN         NaN                   NaN                NaN
#  4                 NaN         NaN                   NaN                NaN
#  ..                ...         ...                   ...                ...
#  65                NaN         NaN                   NaN                NaN
#  66                NaN         NaN                   NaN                NaN
#  67                NaN         NaN                   NaN                NaN
#  68                NaN         NaN                   NaN                NaN
#  69                NaN         NaN                   NaN                NaN
#
#      Last Push Token Update  Last Device Settings Update  Last OS Version  \
#  0                      NaN                          NaN              NaN
#  1                      NaN                          NaN              NaN
#  2                      NaN                          NaN              NaN
#  3                      NaN                          NaN              NaN
#  4                      NaN                          NaN              NaN
#  ..                     ...                          ...              ...
#  65                     NaN                          NaN              NaN
#  66                     NaN                          NaN              NaN
#  67                     NaN                          NaN              NaN
#  68                     NaN                          NaN              NaN
#  69                     NaN                          NaN              NaN
#
#      App Version Code  App Version Name  Last Heartbeat  \
#  0                NaN               NaN             NaN
#  1                NaN               NaN             NaN
#  2                NaN               NaN             NaN
#  3                NaN               NaN             NaN
#  4                NaN               NaN             NaN
#  ..               ...               ...             ...
#  65               NaN               NaN             NaN
#  66               NaN               NaN             NaN
#  67               NaN               NaN             NaN
#  68               NaN               NaN             NaN
#  69               NaN               NaN             NaN
#
#                      Study_ID    Study_Name
#  0   598365d5388cd66a62ac1f9e  trial_phase2
#  1   598365d5388cd66a62ac1f9e  trial_phase2
#  2   598365d5388cd66a62ac1f9e  trial_phase2
#  3   598365d5388cd66a62ac1f9e  trial_phase2
#  4   598365d5388cd66a62ac1f9e  trial_phase2
#  ..                       ...           ...
#  65  598365d5388cd66a62ac1f9e  trial_phase2
#  66  598365d5388cd66a62ac1f9e  trial_phase2
#  67  598365d5388cd66a62ac1f9e  trial_phase2
#  68  598365d5388cd66a62ac1f9e  trial_phase2
#  69  598365d5388cd66a62ac1f9e  trial_phase2
#
#  [70 rows x 17 columns],
#      Created On Patient ID          Status  OS Type    First Registration Date  \
#  0   2018-05-22   1rkt87d2        Inactive      IOS  2019-04-16 19:00:00 (UTC)
#  1   2018-05-22    3j2fdbb        Inactive  ANDROID  2018-09-13 16:00:00 (UTC)
#  2   2018-05-22   3tg2dbdl        Inactive      IOS  2019-12-20 17:00:00 (UTC)
#  3   2018-05-22   4fyd1ssv        Inactive      IOS  2019-02-28 15:00:00 (UTC)
#  4   2018-05-22   4s7o5pps        Inactive      IOS  2018-09-25 17:00:00 (UTC)
#  ..         ...        ...             ...      ...                        ...
#  57  2018-05-22   ukexs41t        Inactive      IOS  2019-07-25 14:00:00 (UTC)
#  58  2018-05-22   unlkfxnc        Inactive      IOS  2018-08-30 15:00:00 (UTC)
#  59  2018-05-22   vby6fos4        Inactive      IOS  2018-11-08 18:00:00 (UTC)
#  60  2020-01-22   x3sh7qc8  Not Registered      NaN                        NaN
#  61  2018-05-22   ymmc6po3  Not Registered      NaN                        NaN
#
#      Last Registration Last Upload Last Survey Download  Last Set Password  \
#  0                 NaN         NaN                  NaN                NaN
#  1                 NaN         NaN                  NaN                NaN
#  2                 NaN         NaN                  NaN                NaN
#  3                 NaN         NaN                  NaN                NaN
#  4                 NaN         NaN                  NaN                NaN
#  ..                ...         ...                  ...                ...
#  57                NaN         NaN                  NaN                NaN
#  58                NaN         NaN                  NaN                NaN
#  59                NaN         NaN                  NaN                NaN
#  60                NaN         NaN                  NaN                NaN
#  61                NaN         NaN                  NaN                NaN
#
#      Last Push Token Update  Last Device Settings Update  Last OS Version  \
#  0                      NaN                          NaN              NaN
#  1                      NaN                          NaN              NaN
#  2                      NaN                          NaN              NaN
#  3                      NaN                          NaN              NaN
#  4                      NaN                          NaN              NaN
#  ..                     ...                          ...              ...
#  57                     NaN                          NaN              NaN
#  58                     NaN                          NaN              NaN
#  59                     NaN                          NaN              NaN
#  60                     NaN                          NaN              NaN
#  61                     NaN                          NaN              NaN
#
#      App Version Code  App Version Name  Last Heartbeat  \
#  0                NaN               NaN             NaN
#  1                NaN               NaN             NaN
#  2                NaN               NaN             NaN
#  3                NaN               NaN             NaN
#  4                NaN               NaN             NaN
#  ..               ...               ...             ...
#  57               NaN               NaN             NaN
#  58               NaN               NaN             NaN
#  59               NaN               NaN             NaN
#  60               NaN               NaN             NaN
#  61               NaN               NaN             NaN
#
#                      Study_ID                      Study_Name
#  0   5a2ae1dc03d3c425ef0ea752  trial_phase2_passive_data_only
#  1   5a2ae1dc03d3c425ef0ea752  trial_phase2_passive_data_only
#  2   5a2ae1dc03d3c425ef0ea752  trial_phase2_passive_data_only
#  3   5a2ae1dc03d3c425ef0ea752  trial_phase2_passive_data_only
#  4   5a2ae1dc03d3c425ef0ea752  trial_phase2_passive_data_only
#  ..                       ...                             ...
#  57  5a2ae1dc03d3c425ef0ea752  trial_phase2_passive_data_only
#  58  5a2ae1dc03d3c425ef0ea752  trial_phase2_passive_data_only
#  59  5a2ae1dc03d3c425ef0ea752  trial_phase2_passive_data_only
#  60  5a2ae1dc03d3c425ef0ea752  trial_phase2_passive_data_only
#  61  5a2ae1dc03d3c425ef0ea752  trial_phase2_passive_data_only
#
#  [62 rows x 17 columns],
#     Created On Patient ID    Status  OS Type    First Registration Date  \
#  0  2018-02-11   4sgli41i  Inactive      IOS  2018-02-12 02:00:00 (UTC)
#  1  2018-02-21   5raarz6v  Inactive  ANDROID  2018-02-21 20:00:00 (UTC)
#  2  2018-02-06   izdho8xu  Inactive      IOS  2018-02-06 21:00:00 (UTC)
#
#     Last Registration  Last Upload  Last Survey Download  Last Set Password  \
#  0                NaN          NaN                   NaN                NaN
#  1                NaN          NaN                   NaN                NaN
#  2                NaN          NaN                   NaN                NaN
#
#     Last Push Token Update  Last Device Settings Update  Last OS Version  \
#  0                     NaN                          NaN              NaN
#  1                     NaN                          NaN              NaN
#  2                     NaN                          NaN              NaN
#
#     App Version Code  App Version Name  Last Heartbeat  \
#  0               NaN               NaN             NaN
#  1               NaN               NaN             NaN
#  2               NaN               NaN             NaN
#
#                     Study_ID       Study_Name
#  0  5a79f17d03d3c45080924ed4  troubleshooting
#  1  5a79f17d03d3c45080924ed4  troubleshooting
#  2  5a79f17d03d3c45080924ed4  troubleshooting  ]

# %%
# Merge all dfs vertically
if dataframes:
    combined_df = pd.concat(dataframes, axis=0, ignore_index=True) 
    print(f"\nFinal merged dataframe has {combined_df.shape[0]} rows and {combined_df.shape[1]} columns")

    # Save the merged DataFrame to a CSV file
    output_path = os.path.join(data_dir, "merged_participants.csv")
    combined_df.to_csv(output_path, index=False)
    print(f"Merged file saved to: {output_path}")
else:
    print("No valid CSV files to merge.")
# Out:
# Final merged dataframe has 158 rows and 17 columns
# Merged file saved to: /n/onnela_dp_l3/Lab/HOPE/beiwe/data/merged_participants.csv

# %%
import pandas as pd
import re

def clean_names(df, clean_index=False):
    """
    Cleans column names (and optionally index names) by:
    - Stripping whitespace
    - Replacing spaces with underscores
    - Lowercasing
    - Removing non-alphanumeric characters (except underscore)
    """
    df = df.copy()  # optional: avoid modifying original dataframe

    df.columns = (
        df.columns.str.strip()
                  .str.replace(' ', '_')
                  .str.lower()
                  .str.replace(r"[^\w]", "", regex=True)
    )

    if clean_index:
        df.index = (
            df.index.str.strip()
                    .str.replace(' ', '_')
                    .str.lower()
                    .str.replace(r"[^\w]", "", regex=True)
        )

    return df

# %%
combined_df = clean_names(combined_df)

combined_df.head()

# rename Patient ID to "beiwe_id" 
combined_df.rename(columns={"Patient ID": "beiwe_id"}, inplace=True)

# %%
combined_df.head()
# Out:
#    created_on  beiwe_id          status os_type    first_registration_date  \
# 0  2020-07-30  h6qsyvyf        Inactive     IOS  2020-07-30 14:00:00 (UTC)
# 1  2020-05-02  k75kp9va        Inactive     IOS  2020-05-04 02:00:00 (UTC)
# 2  2020-04-29  lz3g8h3d        Inactive     IOS  2020-04-29 13:00:00 (UTC)
# 3  2020-05-07  sqdpv78e        Inactive     IOS  2020-05-07 17:00:00 (UTC)
# 4  2020-02-07  1wlgkwod  Not Registered     NaN                        NaN
#
#    last_registration last_upload last_survey_download  last_set_password  \
# 0                NaN         NaN                  NaN                NaN
# 1                NaN         NaN                  NaN                NaN
# 2                NaN         NaN                  NaN                NaN
# 3                NaN         NaN                  NaN                NaN
# 4                NaN         NaN                  NaN                NaN
#
#    last_push_token_update  last_device_settings_update  last_os_version  \
# 0                     NaN                          NaN              NaN
# 1                     NaN                          NaN              NaN
# 2                     NaN                          NaN              NaN
# 3                     NaN                          NaN              NaN
# 4                     NaN                          NaN              NaN
#
#    app_version_code  app_version_name  last_heartbeat  \
# 0               NaN               NaN             NaN
# 1               NaN               NaN             NaN
# 2               NaN               NaN             NaN
# 3               NaN               NaN             NaN
# 4               NaN               NaN             NaN
#
#                    study_id study_name
# 0  5h7D9XT2vrN3BWkdcbYVNtpI      test2
# 1  5h7D9XT2vrN3BWkdcbYVNtpI      test2
# 2  5h7D9XT2vrN3BWkdcbYVNtpI      test2
# 3  5h7D9XT2vrN3BWkdcbYVNtpI      test2
# 4  59c2b5b4388cd6715a958247       test

# %%
# pull demographic table
DEMO_TB_NAME = "HOPE_paper2_demographics.csv"
demo_tb_path = os.path.abspath(os.path.join(data_dir, DEMO_TB_NAME))
demo_df = pd.read_csv(demo_tb_path)

# %%
demo_df.head()
# Out:
#    Unnamed: 0    ID  Gender  Age  Height (cm)  Weight (kg)    BMI  \
# 0           0  1001  Female   64        162.6         79.4  30.00
# 1           1  1002  Female   70        154.9         67.3  28.05
# 2           2  1003  Female   56        165.4         62.5  22.85
# 3           3  1004  Female   56        160.0         54.5  21.29
# 4           4  1005  Female   57        157.5         68.5  27.61
#
#   Health status (Type of cancer / Stage / Performance status)  \
# 0                                            Ovarian
# 1                                            Ovarian
# 2                                            Ovarian
# 3                                           Cervical
# 4                                            Ovarian
#
#            base_disease_site  Unnamed: 8  Unnamed: 9  Unnamed: 10       OS  \
# 0                      White         NaN         NaN          NaN  Android
# 1            Other (specify)         NaN         1.0          NaN      iOS
# 2  Black or African American         NaN         1.0          NaN      iOS
# 3                      White         NaN         2.0          NaN      iOS
# 4  Black or African American         NaN         1.0          NaN      iOS
#
#    Beiwe ID
# 0  jy8yzsap
# 1  md7fnll7
# 2  wrb5oh7u
# 3  wgs5rptp
# 4  q21jny47

# %%
demo_df = clean_names(demo_df)
demo_df.head()
# Out:
#    unnamed_0    id  gender  age  height_cm  weight_kg    bmi  \
# 0          0  1001  Female   64      162.6       79.4  30.00
# 1          1  1002  Female   70      154.9       67.3  28.05
# 2          2  1003  Female   56      165.4       62.5  22.85
# 3          3  1004  Female   56      160.0       54.5  21.29
# 4          4  1005  Female   57      157.5       68.5  27.61
#
#   health_status_type_of_cancer__stage__performance_status  \
# 0                                            Ovarian
# 1                                            Ovarian
# 2                                            Ovarian
# 3                                           Cervical
# 4                                            Ovarian
#
#            base_disease_site  unnamed_8  unnamed_9  unnamed_10       os  \
# 0                      White        NaN        NaN         NaN  Android
# 1            Other (specify)        NaN        1.0         NaN      iOS
# 2  Black or African American        NaN        1.0         NaN      iOS
# 3                      White        NaN        2.0         NaN      iOS
# 4  Black or African American        NaN        1.0         NaN      iOS
#
#    beiwe_id
# 0  jy8yzsap
# 1  md7fnll7
# 2  wrb5oh7u
# 3  wgs5rptp
# 4  q21jny47

# %%
demo_df_merged= pd.merge(demo_df, combined_df, on="beiwe_id", how="inner")

# %%
demo_df_merged.head()
# Out:
#    unnamed_0    id  gender  age  height_cm  weight_kg    bmi  \
# 0          0  1001  Female   64      162.6       79.4  30.00
# 1          1  1002  Female   70      154.9       67.3  28.05
# 2          2  1003  Female   56      165.4       62.5  22.85
# 3          3  1004  Female   56      160.0       54.5  21.29
# 4          4  1005  Female   57      157.5       68.5  27.61
#
#   health_status_type_of_cancer__stage__performance_status  \
# 0                                            Ovarian
# 1                                            Ovarian
# 2                                            Ovarian
# 3                                           Cervical
# 4                                            Ovarian
#
#            base_disease_site  unnamed_8  ...  last_survey_download  \
# 0                      White        NaN  ...                   NaN
# 1            Other (specify)        NaN  ...                   NaN
# 2  Black or African American        NaN  ...                   NaN
# 3                      White        NaN  ...                   NaN
# 4  Black or African American        NaN  ...                   NaN
#
#    last_set_password last_push_token_update last_device_settings_update  \
# 0                NaN                    NaN                         NaN
# 1                NaN                    NaN                         NaN
# 2                NaN                    NaN                         NaN
# 3                NaN                    NaN                         NaN
# 4                NaN                    NaN                         NaN
#
#   last_os_version app_version_code app_version_name last_heartbeat  \
# 0             NaN              NaN              NaN            NaN
# 1             NaN              NaN              NaN            NaN
# 2             NaN              NaN              NaN            NaN
# 3             NaN              NaN              NaN            NaN
# 4             NaN              NaN              NaN            NaN
#
#                    study_id study_name
# 0  588224eff4d48a76f488cdfd      trial
# 1  588224eff4d48a76f488cdfd      trial
# 2  588224eff4d48a76f488cdfd      trial
# 3  588224eff4d48a76f488cdfd      trial
# 4  588224eff4d48a76f488cdfd      trial
#
# [5 rows x 30 columns]

# %%
demo_df_merged.to_csv(os.path.abspath(os.path.join(data_dir, "HOPE_paper2_demographics_w_study.csv")))

# %%
# version just containing Beiwe_ID, Study_Name, Study_ID
demo_df_sharing = demo_df_merged[["beiwe_id", "study_name", "study_id"]]
demo_df_sharing.to_csv(os.path.abspath(os.path.join(data_dir, "HOPE_paper2_studies_and_ids_sharing.csv")))
